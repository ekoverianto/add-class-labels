# %%
f_open = open('sample_data/AppleStore.csv') #select repository for your data

from csv import reader
f_read = reader(f_open)
data = list(f_read)

#if the price of the app is 0.0, print 'free', else print 'buy'
for val in data[1:]:
  price = float(val[5])
  if price == 0.0:
    val.append('Free')
  else:
    val.append('Buy')
    
data[0].append('Free Or Buy')

#converting list of lists into a table
import pandas as pd
pd.DataFrame(data[:11])
# Out:
#     0          1   ...       16           17
# 0              id  ...  vpp_lic  Free Or Buy
# 1    1  281656475  ...        1          Buy
# 2    2  281796108  ...        1         Free
# 3    3  281940292  ...        1         Free
# 4    4  282614216  ...        1         Free
# 5    5  282935706  ...        1         Free
# 6    6  283619399  ...        1          Buy
# 7    7  283646709  ...        1         Free
# 8    8  284035177  ...        1         Free
# 9    9  284666222  ...        1          Buy
# 10  10  284736660  ...        1          Buy
#
# [11 rows x 18 columns]
